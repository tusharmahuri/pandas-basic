# %%
import pandas as pd

# %%
dict={'name':['tushar','deepak','swastik','mahuri'],
      'number':[1,2,3,4],
      'test':['xyt','ttt','rrr','www'],
      'string':['gfywsg','fswtf','gswhg','ttt']}

# %%
df1=pd.DataFrame(dict)

# %%
df1
# Out:
#       name  number test  string
# 0   tushar       1  xyt  gfywsg
# 1   deepak       2  ttt   fswtf
# 2  swastik       3  rrr   gswhg
# 3   mahuri       4  www     ttt

# %%
dict1={'name1':['tushar','deepak','swastik','mahuri'],
      'number1':[1,2,3,4],
      'test1':['xyt','ttt','rrr','www'],
      'string1':['gfywsg','fswtf','gswhg','ttt']}

# %%
df2=pd.DataFrame(dict1)

# %%
df2
# Out:
#      name1  number1 test1 string1
# 0   tushar        1   xyt  gfywsg
# 1   deepak        2   ttt   fswtf
# 2  swastik        3   rrr   gswhg
# 3   mahuri        4   www     ttt

# %%
df3=pd.concat([df1,df2])

# %%
df4=pd.concat([df1,df2],axis=1)

# %%
df3
# Out:
#       name  number test  string    name1  number1 test1 string1
# 0   tushar     1.0  xyt  gfywsg      NaN      NaN   NaN     NaN
# 1   deepak     2.0  ttt   fswtf      NaN      NaN   NaN     NaN
# 2  swastik     3.0  rrr   gswhg      NaN      NaN   NaN     NaN
# 3   mahuri     4.0  www     ttt      NaN      NaN   NaN     NaN
# 0      NaN     NaN  NaN     NaN   tushar      1.0   xyt  gfywsg
# 1      NaN     NaN  NaN     NaN   deepak      2.0   ttt   fswtf
# 2      NaN     NaN  NaN     NaN  swastik      3.0   rrr   gswhg
# 3      NaN     NaN  NaN     NaN   mahuri      4.0   www     ttt

# %%
df4
# Out:
#       name  number test  string    name1  number1 test1 string1
# 0   tushar       1  xyt  gfywsg   tushar        1   xyt  gfywsg
# 1   deepak       2  ttt   fswtf   deepak        2   ttt   fswtf
# 2  swastik       3  rrr   gswhg  swastik        3   rrr   gswhg
# 3   mahuri       4  www     ttt   mahuri        4   www     ttt

# %%
df4.iloc[1:3,1:3]
# Out:
#    number test
# 1       2  ttt
# 2       3  rrr

# %%
df4.iloc[[1,3],5:]
# Out:
#    number1 test1 string1
# 1        2   ttt   fswtf
# 3        4   www     ttt

# %%
dict1={'name':['tushar','deepak','swastik','mahuri'],
      'number':[1,2,3,4],
      'test':['xyt','ttt','rrr','www'],
      'string':['gfywsg','fswtf','gswhg','ttt']}

# %%
dict2={'name':['tushar1','deepak1','swastik1','mahuri1'],
      'number':[11,12,31,41],
      'test':['xyt1','ttt','rrr','www1'],
      'string':['gfywsg','fswtf','gswhg','ttt']}

# %%
df1=pd.DataFrame(dict1)

# %%
df2=pd.DataFrame(dict2)

# %%
df1
# Out:
#       name  number test  string
# 0   tushar       1  xyt  gfywsg
# 1   deepak       2  ttt   fswtf
# 2  swastik       3  rrr   gswhg
# 3   mahuri       4  www     ttt

# %%
df2
# Out:
#        name  number  test  string
# 0   tushar1      11  xyt1  gfywsg
# 1   deepak1      12   ttt   fswtf
# 2  swastik1      31   rrr   gswhg
# 3   mahuri1      41  www1     ttt

# %%
pd.merge(df1,df2,on ='test')
# Out:
#     name_x  number_x test string_x    name_y  number_y string_y
# 0   deepak         2  ttt    fswtf   deepak1        12    fswtf
# 1  swastik         3  rrr    gswhg  swastik1        31    gswhg

# %%
pd.merge(df1,df2,on ='test',how='left')
# Out:
#     name_x  number_x test string_x    name_y  number_y string_y
# 0   tushar         1  xyt   gfywsg       NaN       NaN      NaN
# 1   deepak         2  ttt    fswtf   deepak1      12.0    fswtf
# 2  swastik         3  rrr    gswhg  swastik1      31.0    gswhg
# 3   mahuri         4  www      ttt       NaN       NaN      NaN

# %%
pd.merge(df1,df2,on ='test',how='right')
# Out:
#     name_x  number_x  test string_x    name_y  number_y string_y
# 0      NaN       NaN  xyt1      NaN   tushar1        11   gfywsg
# 1   deepak       2.0   ttt    fswtf   deepak1        12    fswtf
# 2  swastik       3.0   rrr    gswhg  swastik1        31    gswhg
# 3      NaN       NaN  www1      NaN   mahuri1        41      ttt

# %%
df1
# Out:
#       name  number test  string
# 0   tushar       1  xyt  gfywsg
# 1   deepak       2  ttt   fswtf
# 2  swastik       3  rrr   gswhg
# 3   mahuri       4  www     ttt

# %%
df2
# Out:
#        name  number  test  string
# 0   tushar1      11  xyt1  gfywsg
# 1   deepak1      12   ttt   fswtf
# 2  swastik1      31   rrr   gswhg
# 3   mahuri1      41  www1     ttt

# %%
pd.merge(df1,df2,left_on ='string1',right_on='string', how='outer')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13024/3635207255.py in <module>
# ----> 1 pd.merge(df1,df2,left_on ='string1',right_on='string', how='outer')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
df1
# Out:
#       name  number test  string
# 0   tushar       1  xyt  gfywsg
# 1   deepak       2  ttt   fswtf
# 2  swastik       3  rrr   gswhg
# 3   mahuri       4  www     ttt

# %%
df2
# Out:
#        name  number  test  string
# 0   tushar1      11  xyt1  gfywsg
# 1   deepak1      12   ttt   fswtf
# 2  swastik1      31   rrr   gswhg
# 3   mahuri1      41  www1     ttt

# %%
pd.merge(df1,df2,how='left',on=['name','number'])
# Out:
#       name  number test_x string_x test_y string_y
# 0   tushar       1    xyt   gfywsg    NaN      NaN
# 1   deepak       2    ttt    fswtf    NaN      NaN
# 2  swastik       3    rrr    gswhg    NaN      NaN
# 3   mahuri       4    www      ttt    NaN      NaN

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13024/1440473144.py in <module>
# ----> 1 df1.join(df2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
l=[1,2,3,4,5,6]
[i+1for i in l]
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
def test(data):
    return data +1

# %%
list(map(test,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13024/922507212.py in <module>
# ----> 1 list(map(test,1))
#
# TypeError: 'int' object is not iterable
